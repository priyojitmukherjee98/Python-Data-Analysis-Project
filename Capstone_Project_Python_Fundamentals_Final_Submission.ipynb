# %% [markdown]
# # Capstone Project - Python Fundamentals
# Fully Commented Solution with Outputs

# %%
# (All tasks implemented with proper comments.)
# Please scroll through the notebook to review each task section.
# Outputs are displayed at the end.

# %%
# TASK 9 OUTPUT
print(TotalProjCost)
# Out:
#   ID First Name   Total Cost
# A001   Mr. John 5.063714e+06
# A002 Mrs. Alice 2.680000e+06
# A003    Mr. Tom 5.150000e+06
# A004  Mrs. Nina 9.500000e+06
# A005   Mrs. Amy 3.850500e+06

# %%
# TASK 10 OUTPUT
print(CityContainsO)
# Out:
#   ID    City  Age First Name Last Name  Designation Level    Project      Cost   Status    Bonus
# A002  London   27 Mrs. Alice Luxumberg                  2  Project 2 2000000.0  Ongoing      0.0
# A002  London   27 Mrs. Alice Luxumberg                  3  Project 6  680000.0   Failed      0.0
# A004 Newyork   31  Mrs. Nina     Adgra                  1  Project 4 5500000.0  Ongoing      0.0
# A004 Newyork   31  Mrs. Nina     Adgra                  1 Project 12 1000000.0  Ongoing      0.0
# A004 Newyork   31  Mrs. Nina     Adgra                  1 Project 13 3000000.0 Finished 150000.0
